# %% [markdown]
# <a href="https://colab.research.google.com/github/arcparagon/Jobsheet_PVCK2021/blob/main/Week5JobsheetPCVK.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Jobsheet 5 PCVK (Pemrograman Citra dan Visi Komputer**
#
# Nama : Alief Al Gaffari
#
# Kelas : TI-3E
#
# NIM : 1841720149

# %% [markdown]
# **Nomor 1**

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
import math

# %%
print('Gamma Correction on Citra')
print('-------------------------------------')
try:
  gamma = int(input('Enter Gamma Input here :'))
except ValueError:
  print('Sorry, not a number. Try Again')

original = cv.imread('/content/drive/MyDrive/Images/female.tiff')
gamma_image = np.zeros(original.shape, original.dtype)

#access every pixel
for y in range(original.shape[0]):
  for x in range(original.shape[1]):
    for c in range(original.shape[2]):
      gamma_image[y,x,c] = np.clip(255 * pow(original[y,x,c]/255,(1/gamma)),0,255)

final_frame = cv.hconcat((original, gamma_image))
cv2_imshow(final_frame)
# Out:
# Gamma Correction on Citra
# -------------------------------------
# Enter Gamma Input here :10
# <PIL.Image.Image image mode=RGB size=512x256 at 0x7F0910ECC4D0>

# %% [markdown]
# **Nomor 3**

# %%
from matplotlib import pyplot as plt

print('Gamma Correction on Citra')
print('-------------------------------------------')
try:
  db = int(input("Enter db points : "))
except ValueError:
  print('Sorry, this is not a number. Please Try Again')

  img2 = cv.imread('/content/drive/MyDrive/Images/kitten01.jpg')

  dst = cv.fastN1MeansDenoisingColored(img2, None, 10, db, 7,15)

  final_frame = cv.hconcat((img2,dst))
  cv2_imshow(final_frame)
# Out:
# Gamma Correction on Citra
# -------------------------------------------
# Enter db points : 70

# %% [markdown]
# **Nomor 4**

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow 
from skimage import io 
import matplotlib.pyplot as plt 
import numpy as np

img = cv.imread('/content/drive/MyDrive/Images/teeth.jpg')
mask = np.zeros(img.shape, dtype=np.uint8)
mask = cv.circle(mask, (260, 300), 225, (255,255,255), -1)

result = img | mask

final_frame = cv.hconcat((img, mask, result))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=4062x1036 at 0x7F5BFDC78790>

# %%
from google.colab.patches import cv2_imshow 
from skimage import io 
import matplotlib.pyplot as plt 
import numpy as np

img = cv.imread('/content/drive/MyDrive/Images/teeth.jpg')
mask = np.zeros(img.shape, dtype=np.uint8)
mask = cv.circle(mask, (260, 300), 225, (255,255,255), -1)

result = ~img & ~mask

final_frame = cv.hconcat((img, mask, result))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=4062x1036 at 0x7F5BFA349CD0>
